# %%
symbol_table = dict()
ADDRESS = 0 




def is_label(line):
    if '(' in line and ')' in line:
        return True
    return False

def is_symbol(line):
    if '@' in line:
        if line.split('@')[1].isdigit():
            return False
        else:
            return True
    return False



def comp(line):
    if '=' in line:
        return True
    return False
    

def decode_comp(line):
    dest, rem = line.split('=')
    jmp = None
    if ';' in rem:
        op, jmp = rem.split(';')
    else:
        op = rem
    return dest, op, jmp



def to_binary_A()


def to_binary_C()


decode_comp('D=D+1')
# Out:
# ('D', 'D+1', None)

# %%
'1@r2'.split('@')
# Out:
# ['1', 'r2']
